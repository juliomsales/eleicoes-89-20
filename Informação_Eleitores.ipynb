# %% [markdown]
# # Bibliotecas

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.2f}'.format
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Dados

# %%
df1989 = pd.read_csv(
    'info_eleitores/DETALHE_VOTACAO_UF_1989.txt',
    sep=';',
    encoding='ISO-8859-1',
    header=None,
)
df1989.drop([0, 1, 4, 6, 7, 15, 16, 17, 18, 19, 20, 21], axis=1, inplace=True)
df1989.columns = [
    'ANO_ELEICAO', 'NR_TURNO', 'SG_UF', 'DS_CARGO', 'QT_APTOS',
    'QT_COMPARECIMENTO', 'QT_ABSTENCOES', 'QT_VOTOS_NOMINAIS',
    'QT_VOTOS_BRANCOS', 'QT_VOTOS_NULOS'
]
df1989['QT_VOTOS_LEGENDA'] = 0

# %%
datasets = [
    'DETALHE_VOTACAO_UF_1990_AL.txt', 'DETALHE_VOTACAO_UF_1990_AM.txt',
    'DETALHE_VOTACAO_UF_1990_AP.txt', 'DETALHE_VOTACAO_UF_1990_BA.txt',
    'DETALHE_VOTACAO_UF_1990_CE.txt', 'DETALHE_VOTACAO_UF_1990_DF.txt',
    'DETALHE_VOTACAO_UF_1990_ES.txt', 'DETALHE_VOTACAO_UF_1990_GO.txt',
    'DETALHE_VOTACAO_UF_1990_MA.txt', 'DETALHE_VOTACAO_UF_1990_MG.txt',
    'DETALHE_VOTACAO_UF_1990_MS.txt', 'DETALHE_VOTACAO_UF_1990_MT.txt',
    'DETALHE_VOTACAO_UF_1990_PA.txt', 'DETALHE_VOTACAO_UF_1990_PB.txt',
    'DETALHE_VOTACAO_UF_1990_PE.txt', 'DETALHE_VOTACAO_UF_1990_PI.txt',
    'DETALHE_VOTACAO_UF_1990_PR.txt', 'DETALHE_VOTACAO_UF_1990_RJ.txt',
    'DETALHE_VOTACAO_UF_1990_RN.txt', 'DETALHE_VOTACAO_UF_1990_RO.txt',
    'DETALHE_VOTACAO_UF_1990_RR.txt', 'DETALHE_VOTACAO_UF_1990_RS.txt',
    'DETALHE_VOTACAO_UF_1990_SC.txt', 'DETALHE_VOTACAO_UF_1990_SE.txt',
    'DETALHE_VOTACAO_UF_1990_SP.txt', 'DETALHE_VOTACAO_UF_1990_TO.txt'
]

df1990 = pd.read_csv('info_eleitores/DETALHE_VOTACAO_UF_1990_AC.txt',
                     error_bad_lines=False,
                     header=None,
                     sep=';',
                     encoding="ISO-8859-1")
for data in datasets:
    df = pd.read_csv('info_eleitores/' + data,
                     error_bad_lines=False,
                     header=None,
                     sep=';',
                     encoding="ISO-8859-1")
    df1990 = pd.concat([df1990, df])
df1990.drop([0, 1, 4, 6, 7, 16, 17, 18, 19, 20, 21], axis=1, inplace=True)
df1990.columns = [
    'ANO_ELEICAO', 'NR_TURNO', 'SG_UF', 'DS_CARGO', 'QT_APTOS',
    'QT_COMPARECIMENTO', 'QT_ABSTENCOES', 'QT_VOTOS_NOMINAIS',
    'QT_VOTOS_BRANCOS', 'QT_VOTOS_NULOS', 'QT_VOTOS_LEGENDA'
]

# %%
datasets = [
    'detalhe_votacao_munzona_1994_AL.txt',
    'detalhe_votacao_munzona_1994_AM.txt',
    'detalhe_votacao_munzona_1994_AP.txt',
    'detalhe_votacao_munzona_1994_BA.txt',
    'detalhe_votacao_munzona_1994_GO.txt',
    'detalhe_votacao_munzona_1994_MA.txt',
    'detalhe_votacao_munzona_1994_MS.txt',
    'detalhe_votacao_munzona_1994_PI.txt',
    'detalhe_votacao_munzona_1994_RR.txt',
    'detalhe_votacao_munzona_1994_RS.txt',
    'detalhe_votacao_munzona_1994_SC.txt',
    'detalhe_votacao_munzona_1994_SE.txt',
    'detalhe_votacao_munzona_1994_SP.txt',
    'detalhe_votacao_munzona_1994_TO.txt'
]
df1994 = pd.read_csv('info_eleitores/detalhe_votacao_munzona_1994_AC.txt',
                     error_bad_lines=False,
                     header=None,
                     sep=';',
                     encoding="ISO-8859-1")
for data in datasets:
    df = pd.read_csv('info_eleitores/' + data,
                     error_bad_lines=False,
                     header=None,
                     sep=';',
                     encoding="ISO-8859-1")
    df1994 = pd.concat([df1994, df])
df1994.drop([0, 1, 4, 6, 7, 8, 9, 10, 13, 14, 15, 16, 23, 24, 25], axis=1, inplace=True)
df1994.columns = [
    'ANO_ELEICAO', 'NR_TURNO', 'SG_UF', 'DS_CARGO', 'QT_APTOS',
    'QT_COMPARECIMENTO', 'QT_ABSTENCOES', 'QT_VOTOS_NOMINAIS',
    'QT_VOTOS_BRANCOS', 'QT_VOTOS_NULOS', 'QT_VOTOS_LEGENDA'
]

# %%
datasets = [
    'detalhe_votacao_munzona_1996_AL.txt',
    'detalhe_votacao_munzona_1996_AM.txt',
    'detalhe_votacao_munzona_1996_AP.txt',
    'detalhe_votacao_munzona_1996_BA.txt',
    'detalhe_votacao_munzona_1996_CE.txt',
    'detalhe_votacao_munzona_1996_ES.txt',
    'detalhe_votacao_munzona_1996_GO.txt',
    'detalhe_votacao_munzona_1996_MA.txt',
    'detalhe_votacao_munzona_1996_MG.txt',
    'detalhe_votacao_munzona_1996_MS.txt',
    'detalhe_votacao_munzona_1996_PA.txt',
    'detalhe_votacao_munzona_1996_PB.txt',
    'detalhe_votacao_munzona_1996_PE.txt',
    'detalhe_votacao_munzona_1996_PI.txt',
    'detalhe_votacao_munzona_1996_RN.txt',
    'detalhe_votacao_munzona_1996_RO.txt',
    'detalhe_votacao_munzona_1996_RR.txt',
    'detalhe_votacao_munzona_1996_RS.txt',
    'detalhe_votacao_munzona_1996_SE.txt',
    'detalhe_votacao_munzona_1996_SP.txt',
    'detalhe_votacao_munzona_1996_TO.txt'
]
df1996 = pd.read_csv('info_eleitores/detalhe_votacao_munzona_1996_AC.txt',
                     error_bad_lines=False,
                     header=None,
                     sep=';',
                     encoding="ISO-8859-1")
for data in datasets:
    df = pd.read_csv('info_eleitores/' + data,
                     error_bad_lines=False,
                     header=None,
                     sep=';',
                     encoding="ISO-8859-1")
    df1996 = pd.concat([df1996, df])
df1996.drop([0, 1, 4, 6, 7, 8, 9, 10, 13, 14, 15, 16, 23, 24, 25], axis=1, inplace=True)
df1996.columns = [
    'ANO_ELEICAO', 'NR_TURNO', 'SG_UF', 'DS_CARGO', 'QT_APTOS',
    'QT_COMPARECIMENTO', 'QT_ABSTENCOES', 'QT_VOTOS_NOMINAIS',
    'QT_VOTOS_BRANCOS', 'QT_VOTOS_NULOS', 'QT_VOTOS_LEGENDA'
]

# %%
datasets = [
    'detalhe_votacao_munzona_1998_AL.txt',
    'detalhe_votacao_munzona_1998_AM.txt',
    'detalhe_votacao_munzona_1998_AP.txt',
    'detalhe_votacao_munzona_1998_BA.txt',
    'detalhe_votacao_munzona_1998_BR.txt',
    'detalhe_votacao_munzona_1998_CE.txt',
    'detalhe_votacao_munzona_1998_DF.txt',
    'detalhe_votacao_munzona_1998_ES.txt',
    'detalhe_votacao_munzona_1998_GO.txt',
    'detalhe_votacao_munzona_1998_MA.txt',
    'detalhe_votacao_munzona_1998_MG.txt',
    'detalhe_votacao_munzona_1998_MS.txt',
    'detalhe_votacao_munzona_1998_MT.txt',
    'detalhe_votacao_munzona_1998_PA.txt',
    'detalhe_votacao_munzona_1998_PB.txt',
    'detalhe_votacao_munzona_1998_PE.txt',
    'detalhe_votacao_munzona_1998_PI.txt',
    'detalhe_votacao_munzona_1998_PR.txt',
    'detalhe_votacao_munzona_1998_RJ.txt',
    'detalhe_votacao_munzona_1998_RN.txt',
    'detalhe_votacao_munzona_1998_RO.txt',
    'detalhe_votacao_munzona_1998_RR.txt',
    'detalhe_votacao_munzona_1998_RS.txt',
    'detalhe_votacao_munzona_1998_SC.txt',
    'detalhe_votacao_munzona_1998_SE.txt',
    'detalhe_votacao_munzona_1998_SP.txt',
    'detalhe_votacao_munzona_1998_TO.txt',
    'detalhe_votacao_munzona_1998_ZZ.txt'
]

df1998 = pd.read_csv('info_eleitores/detalhe_votacao_munzona_1998_AC.txt',
                     error_bad_lines=False,
                     header=None,
                     sep=';',
                     encoding="ISO-8859-1")
for data in datasets:
    df = pd.read_csv('info_eleitores/' + data,
                     error_bad_lines=False,
                     header=None,
                     sep=';',
                     encoding="ISO-8859-1")
    df1998 = pd.concat([df1998, df])
df1998.drop([0, 1, 4, 6, 7, 8, 9, 10, 13, 14, 15, 16, 23, 24, 25], axis=1, inplace=True)
df1998.columns = [
    'ANO_ELEICAO', 'NR_TURNO', 'SG_UF', 'DS_CARGO', 'QT_APTOS',
    'QT_COMPARECIMENTO', 'QT_ABSTENCOES', 'QT_VOTOS_NOMINAIS',
    'QT_VOTOS_BRANCOS', 'QT_VOTOS_NULOS', 'QT_VOTOS_LEGENDA'
]

# %%
datasets = [
    'detalhe_votacao_munzona_2000_AL.txt',
    'detalhe_votacao_munzona_2000_AM.txt',
    'detalhe_votacao_munzona_2000_AP.txt',
    'detalhe_votacao_munzona_2000_BA.txt',
    'detalhe_votacao_munzona_2000_CE.txt',
    'detalhe_votacao_munzona_2000_ES.txt',
    'detalhe_votacao_munzona_2000_GO.txt',
    'detalhe_votacao_munzona_2000_MA.txt',
    'detalhe_votacao_munzona_2000_MG.txt',
    'detalhe_votacao_munzona_2000_MS.txt',
    'detalhe_votacao_munzona_2000_MT.txt',
    'detalhe_votacao_munzona_2000_PA.txt',
    'detalhe_votacao_munzona_2000_PB.txt',
    'detalhe_votacao_munzona_2000_PE.txt',
    'detalhe_votacao_munzona_2000_PI.txt',
    'detalhe_votacao_munzona_2000_PR.txt',
    'detalhe_votacao_munzona_2000_RJ.txt',
    'detalhe_votacao_munzona_2000_RN.txt',
    'detalhe_votacao_munzona_2000_RO.txt',
    'detalhe_votacao_munzona_2000_RR.txt',
    'detalhe_votacao_munzona_2000_RS.txt',
    'detalhe_votacao_munzona_2000_SC.txt',
    'detalhe_votacao_munzona_2000_SE.txt',
    'detalhe_votacao_munzona_2000_SP.txt',
    'detalhe_votacao_munzona_2000_TO.txt'
]

df2000 = pd.read_csv('info_eleitores/detalhe_votacao_munzona_2000_AC.txt',
                     error_bad_lines=False,
                     header=None,
                     sep=';',
                     encoding="ISO-8859-1")
for data in datasets:
    df = pd.read_csv('info_eleitores/' + data,
                     error_bad_lines=False,
                     header=None,
                     sep=';',
                     encoding="ISO-8859-1")
    df2000 = pd.concat([df2000, df])
df2000.drop([0, 1, 4, 6, 7, 8, 9, 10, 13, 14, 15, 16, 23, 24, 25], axis=1, inplace=True)
df2000.columns = [
    'ANO_ELEICAO', 'NR_TURNO', 'SG_UF', 'DS_CARGO', 'QT_APTOS',
    'QT_COMPARECIMENTO', 'QT_ABSTENCOES', 'QT_VOTOS_NOMINAIS',
    'QT_VOTOS_BRANCOS', 'QT_VOTOS_NULOS', 'QT_VOTOS_LEGENDA'
]

# %%
datasets = [
    'detalhe_votacao_munzona_2002_AL.txt',
    'detalhe_votacao_munzona_2002_AM.txt',
    'detalhe_votacao_munzona_2002_AP.txt',
    'detalhe_votacao_munzona_2002_BA.txt',
    'detalhe_votacao_munzona_2002_BR.txt',
    'detalhe_votacao_munzona_2002_CE.txt',
    'detalhe_votacao_munzona_2002_DF.txt',
    'detalhe_votacao_munzona_2002_ES.txt',
    'detalhe_votacao_munzona_2002_GO.txt',
    'detalhe_votacao_munzona_2002_MA.txt',
    'detalhe_votacao_munzona_2002_MG.txt',
    'detalhe_votacao_munzona_2002_MS.txt',
    'detalhe_votacao_munzona_2002_MT.txt',
    'detalhe_votacao_munzona_2002_PA.txt',
    'detalhe_votacao_munzona_2002_PB.txt',
    'detalhe_votacao_munzona_2002_PE.txt',
    'detalhe_votacao_munzona_2002_PI.txt',
    'detalhe_votacao_munzona_2002_PR.txt',
    'detalhe_votacao_munzona_2002_RJ.txt',
    'detalhe_votacao_munzona_2002_RN.txt',
    'detalhe_votacao_munzona_2002_RO.txt',
    'detalhe_votacao_munzona_2002_RR.txt',
    'detalhe_votacao_munzona_2002_RS.txt',
    'detalhe_votacao_munzona_2002_SC.txt',
    'detalhe_votacao_munzona_2002_SE.txt',
    'detalhe_votacao_munzona_2002_SP.txt',
    'detalhe_votacao_munzona_2002_TO.txt',
    'detalhe_votacao_munzona_2002_ZZ.txt'
]
df2002 = pd.read_csv('info_eleitores/detalhe_votacao_munzona_2002_AC.txt',
                     error_bad_lines=False,
                     header=None,
                     sep=';',
                     encoding="ISO-8859-1")
for data in datasets:
    df = pd.read_csv('info_eleitores/' + data,
                     error_bad_lines=False,
                     header=None,
                     sep=';',
                     encoding="ISO-8859-1")
    df2002 = pd.concat([df2002, df])
df2002.drop([0, 1, 4, 6, 7, 8, 9, 10, 13, 14, 15, 16, 23, 24, 25], axis=1, inplace=True)
df2002.columns = [
    'ANO_ELEICAO', 'NR_TURNO', 'SG_UF', 'DS_CARGO', 'QT_APTOS',
    'QT_COMPARECIMENTO', 'QT_ABSTENCOES', 'QT_VOTOS_NOMINAIS',
    'QT_VOTOS_BRANCOS', 'QT_VOTOS_NULOS', 'QT_VOTOS_LEGENDA'
]

# %%
datasets = [
    'detalhe_votacao_munzona_2004_AL.txt',
    'detalhe_votacao_munzona_2004_AM.txt',
    'detalhe_votacao_munzona_2004_AP.txt',
    'detalhe_votacao_munzona_2004_BA.txt',
    'detalhe_votacao_munzona_2004_CE.txt',
    'detalhe_votacao_munzona_2004_ES.txt',
    'detalhe_votacao_munzona_2004_GO.txt',
    'detalhe_votacao_munzona_2004_MA.txt',
    'detalhe_votacao_munzona_2004_MG.txt',
    'detalhe_votacao_munzona_2004_MS.txt',
    'detalhe_votacao_munzona_2004_MT.txt',
    'detalhe_votacao_munzona_2004_PA.txt',
    'detalhe_votacao_munzona_2004_PB.txt',
    'detalhe_votacao_munzona_2004_PE.txt',
    'detalhe_votacao_munzona_2004_PI.txt',
    'detalhe_votacao_munzona_2004_PR.txt',
    'detalhe_votacao_munzona_2004_RJ.txt',
    'detalhe_votacao_munzona_2004_RN.txt',
    'detalhe_votacao_munzona_2004_RO.txt',
    'detalhe_votacao_munzona_2004_RR.txt',
    'detalhe_votacao_munzona_2004_RS.txt',
    'detalhe_votacao_munzona_2004_SC.txt',
    'detalhe_votacao_munzona_2004_SE.txt',
    'detalhe_votacao_munzona_2004_SP.txt',
    'detalhe_votacao_munzona_2004_TO.txt'
]
df2004 = pd.read_csv('info_eleitores/detalhe_votacao_munzona_2004_AC.txt',
                     error_bad_lines=False,
                     header=None,
                     sep=';',
                     encoding="ISO-8859-1")
for data in datasets:
    df = pd.read_csv('info_eleitores/' + data,
                     error_bad_lines=False,
                     header=None,
                     sep=';',
                     encoding="ISO-8859-1")
    df2004 = pd.concat([df2004, df])
df2004.drop([0, 1, 4, 6, 7, 8, 9, 10, 13, 14, 15, 16, 23, 24, 25],
            axis=1,
            inplace=True)
df2004.columns = [
    'ANO_ELEICAO', 'NR_TURNO', 'SG_UF', 'DS_CARGO', 'QT_APTOS',
    'QT_COMPARECIMENTO', 'QT_ABSTENCOES', 'QT_VOTOS_NOMINAIS',
    'QT_VOTOS_BRANCOS', 'QT_VOTOS_NULOS', 'QT_VOTOS_LEGENDA'
]

# %%
datasets = [
    'detalhe_votacao_munzona_2006_AL.txt',
    'detalhe_votacao_munzona_2006_AM.txt',
    'detalhe_votacao_munzona_2006_AP.txt',
    'detalhe_votacao_munzona_2006_BA.txt',
    'detalhe_votacao_munzona_2006_BR.txt',
    'detalhe_votacao_munzona_2006_CE.txt',
    'detalhe_votacao_munzona_2006_DF.txt',
    'detalhe_votacao_munzona_2006_ES.txt',
    'detalhe_votacao_munzona_2006_GO.txt',
    'detalhe_votacao_munzona_2006_MA.txt',
    'detalhe_votacao_munzona_2006_MG.txt',
    'detalhe_votacao_munzona_2006_MS.txt',
    'detalhe_votacao_munzona_2006_MT.txt',
    'detalhe_votacao_munzona_2006_PA.txt',
    'detalhe_votacao_munzona_2006_PB.txt',
    'detalhe_votacao_munzona_2006_PE.txt',
    'detalhe_votacao_munzona_2006_PI.txt',
    'detalhe_votacao_munzona_2006_PR.txt',
    'detalhe_votacao_munzona_2006_RJ.txt',
    'detalhe_votacao_munzona_2006_RN.txt',
    'detalhe_votacao_munzona_2006_RO.txt',
    'detalhe_votacao_munzona_2006_RR.txt',
    'detalhe_votacao_munzona_2006_RS.txt',
    'detalhe_votacao_munzona_2006_SC.txt',
    'detalhe_votacao_munzona_2006_SE.txt',
    'detalhe_votacao_munzona_2006_SP.txt',
    'detalhe_votacao_munzona_2006_TO.txt',
    'detalhe_votacao_munzona_2006_ZZ.txt'  # Esse está com problema
]
df2006 = pd.read_csv('info_eleitores/detalhe_votacao_munzona_2006_AC.txt',
                     error_bad_lines=False,
                     header=None,
                     sep=';',
                     encoding="ISO-8859-1")
for data in datasets:
    df = pd.read_csv('info_eleitores/' + data,
                     error_bad_lines=False,
                     header=None,
                     sep=';',
                     encoding="ISO-8859-1")
    df2006 = pd.concat([df2006, df])
df2006.drop([0, 1, 4, 6, 7, 8, 9, 10, 13, 14, 15, 16, 23, 24, 25],
            axis=1,
            inplace=True)
df2006.columns = [
    'ANO_ELEICAO', 'NR_TURNO', 'SG_UF', 'DS_CARGO', 'QT_APTOS',
    'QT_COMPARECIMENTO', 'QT_ABSTENCOES', 'QT_VOTOS_NOMINAIS',
    'QT_VOTOS_BRANCOS', 'QT_VOTOS_NULOS', 'QT_VOTOS_LEGENDA'
]

# %%
datasets = [
    'detalhe_votacao_munzona_2008_AL.txt',
    'detalhe_votacao_munzona_2008_AM.txt',
    'detalhe_votacao_munzona_2008_AP.txt',
    'detalhe_votacao_munzona_2008_BA.txt',
    'detalhe_votacao_munzona_2008_CE.txt',
    'detalhe_votacao_munzona_2008_ES.txt',
    'detalhe_votacao_munzona_2008_GO.txt',
    'detalhe_votacao_munzona_2008_MA.txt',
    'detalhe_votacao_munzona_2008_MG.txt',
    'detalhe_votacao_munzona_2008_MS.txt',
    'detalhe_votacao_munzona_2008_MT.txt',
    'detalhe_votacao_munzona_2008_PA.txt',
    'detalhe_votacao_munzona_2008_PB.txt',
    'detalhe_votacao_munzona_2008_PE.txt',
    'detalhe_votacao_munzona_2008_PI.txt',
    'detalhe_votacao_munzona_2008_PR.txt',
    'detalhe_votacao_munzona_2008_RJ.txt',
    'detalhe_votacao_munzona_2008_RN.txt',
    'detalhe_votacao_munzona_2008_RO.txt',
    'detalhe_votacao_munzona_2008_RR.txt',
    'detalhe_votacao_munzona_2008_RS.txt',
    'detalhe_votacao_munzona_2008_SC.txt',
    'detalhe_votacao_munzona_2008_SE.txt',
    'detalhe_votacao_munzona_2008_SP.txt',
    'detalhe_votacao_munzona_2008_TO.txt'
]
df2008 = pd.read_csv('info_eleitores/detalhe_votacao_munzona_2008_AC.txt',
                     error_bad_lines=False,
                     header=None,
                     sep=';',
                     encoding="ISO-8859-1")
for data in datasets:
    df = pd.read_csv('info_eleitores/' + data,
                     error_bad_lines=False,
                     header=None,
                     sep=';',
                     encoding="ISO-8859-1")
    df2008 = pd.concat([df2008, df])
df2008.drop([0, 1, 4, 6, 7, 8, 9, 10, 13, 14, 15, 16, 23, 24, 25],
            axis=1,
            inplace=True)
df2008.columns = [
    'ANO_ELEICAO', 'NR_TURNO', 'SG_UF', 'DS_CARGO', 'QT_APTOS',
    'QT_COMPARECIMENTO', 'QT_ABSTENCOES', 'QT_VOTOS_NOMINAIS',
    'QT_VOTOS_BRANCOS', 'QT_VOTOS_NULOS', 'QT_VOTOS_LEGENDA'
]

# %%
datasets = [
    'detalhe_votacao_munzona_2010_AL.txt',
    'detalhe_votacao_munzona_2010_AM.txt',
    'detalhe_votacao_munzona_2010_AP.txt',
    'detalhe_votacao_munzona_2010_BA.txt',
    'detalhe_votacao_munzona_2010_BR.txt',
    'detalhe_votacao_munzona_2010_CE.txt',
    'detalhe_votacao_munzona_2010_DF.txt',
    'detalhe_votacao_munzona_2010_ES.txt',
    'detalhe_votacao_munzona_2010_GO.txt',
    'detalhe_votacao_munzona_2010_MA.txt',
    'detalhe_votacao_munzona_2010_MG.txt',
    'detalhe_votacao_munzona_2010_MS.txt',
    'detalhe_votacao_munzona_2010_MT.txt',
    'detalhe_votacao_munzona_2010_PA.txt',
    'detalhe_votacao_munzona_2010_PB.txt',
    'detalhe_votacao_munzona_2010_PE.txt',
    'detalhe_votacao_munzona_2010_PI.txt',
    'detalhe_votacao_munzona_2010_PR.txt',
    'detalhe_votacao_munzona_2010_RJ.txt',
    'detalhe_votacao_munzona_2010_RN.txt',
    'detalhe_votacao_munzona_2010_RO.txt',
    'detalhe_votacao_munzona_2010_RR.txt',
    'detalhe_votacao_munzona_2010_RS.txt',
    'detalhe_votacao_munzona_2010_SC.txt',
    'detalhe_votacao_munzona_2010_SE.txt',
    'detalhe_votacao_munzona_2010_SP.txt',
    'detalhe_votacao_munzona_2010_TO.txt',
    'detalhe_votacao_munzona_2010_VT.txt',
    'detalhe_votacao_munzona_2010_ZZ.txt'
]
df2010 = pd.read_csv('info_eleitores/detalhe_votacao_munzona_2010_AC.txt',
                     error_bad_lines=False,
                     header=None,
                     sep=';',
                     encoding="ISO-8859-1")
for data in datasets:
    df = pd.read_csv('info_eleitores/' + data,
                     error_bad_lines=False,
                     header=None,
                     sep=';',
                     encoding="ISO-8859-1")
    df2010 = pd.concat([df2010, df])
df2010.drop([0, 1, 4, 6, 7, 8, 9, 10, 13, 14, 15, 16, 23, 24, 25],
            axis=1,
            inplace=True)
df2010.columns = [
    'ANO_ELEICAO', 'NR_TURNO', 'SG_UF', 'DS_CARGO', 'QT_APTOS',
    'QT_COMPARECIMENTO', 'QT_ABSTENCOES', 'QT_VOTOS_NOMINAIS',
    'QT_VOTOS_BRANCOS', 'QT_VOTOS_NULOS', 'QT_VOTOS_LEGENDA'
]

# %%
datasets = [
    'detalhe_votacao_munzona_2012_AL.txt',
    'detalhe_votacao_munzona_2012_AM.txt',
    'detalhe_votacao_munzona_2012_AP.txt',
    'detalhe_votacao_munzona_2012_BA.txt',
    'detalhe_votacao_munzona_2012_CE.txt',
    'detalhe_votacao_munzona_2012_ES.txt',
    'detalhe_votacao_munzona_2012_GO.txt',
    'detalhe_votacao_munzona_2012_MA.txt',
    'detalhe_votacao_munzona_2012_MG.txt',
    'detalhe_votacao_munzona_2012_MS.txt',
    'detalhe_votacao_munzona_2012_MT.txt',
    'detalhe_votacao_munzona_2012_PA.txt',
    'detalhe_votacao_munzona_2012_PB.txt',
    'detalhe_votacao_munzona_2012_PE.txt',
    'detalhe_votacao_munzona_2012_PI.txt',
    'detalhe_votacao_munzona_2012_PR.txt',
    'detalhe_votacao_munzona_2012_RJ.txt',
    'detalhe_votacao_munzona_2012_RN.txt',
    'detalhe_votacao_munzona_2012_RO.txt',
    'detalhe_votacao_munzona_2012_RR.txt',
    'detalhe_votacao_munzona_2012_RS.txt',
    'detalhe_votacao_munzona_2012_SC.txt',
    'detalhe_votacao_munzona_2012_SE.txt',
    'detalhe_votacao_munzona_2012_SP.txt',
    'detalhe_votacao_munzona_2012_TO.txt'
]
df2012 = pd.read_csv('info_eleitores/detalhe_votacao_munzona_2012_AC.txt',
                     error_bad_lines=False,
                     header=None,
                     sep=';',
                     encoding="ISO-8859-1")
for data in datasets:
    df = pd.read_csv('info_eleitores/' + data,
                     error_bad_lines=False,
                     header=None,
                     sep=';',
                     encoding="ISO-8859-1")
    df2012 = pd.concat([df2012, df])
df2012.drop([0, 1, 4, 6, 7, 8, 9, 10, 13, 14, 15, 16, 23, 24, 25],
            axis=1,
            inplace=True)
df2012.columns = [
    'ANO_ELEICAO', 'NR_TURNO', 'SG_UF', 'DS_CARGO', 'QT_APTOS',
    'QT_COMPARECIMENTO', 'QT_ABSTENCOES', 'QT_VOTOS_NOMINAIS',
    'QT_VOTOS_BRANCOS', 'QT_VOTOS_NULOS', 'QT_VOTOS_LEGENDA'
]

# %%
df2014 = pd.read_csv('info_eleitores/detalhe_votacao_munzona_2014_BRASIL.csv',
                     encoding='ISO-8859-1',
                     sep=';')
df2014.drop([
    'DT_GERACAO', 'HH_GERACAO', 'CD_TIPO_ELEICAO', 'NM_TIPO_ELEICAO',
    'CD_ELEICAO', 'DS_ELEICAO', 'DT_ELEICAO', 'TP_ABRANGENCIA', 'SG_UE',
    'NM_UE', 'NR_ZONA', 'CD_CARGO', 'QT_APTOS_TOT', 'ST_VOTO_EM_TRANSITO',
    'HH_ULTIMA_TOTALIZACAO', 'DT_ULTIMA_TOTALIZACAO', 'QT_SECOES',
    'QT_SECOES_AGREGADAS', 'QT_SECOES_TOT', 'CD_MUNICIPIO', 'NM_MUNICIPIO',
    'QT_VOTOS_PENDENTES'
],
            axis=1,
            inplace=True)

# %%
df2016 = pd.read_csv('info_eleitores/detalhe_votacao_munzona_2016_BRASIL.csv',
                     encoding='ISO-8859-1',
                     sep=';')
df2016.drop([
    'DT_GERACAO', 'HH_GERACAO', 'CD_TIPO_ELEICAO', 'NM_TIPO_ELEICAO',
    'CD_ELEICAO', 'DS_ELEICAO', 'DT_ELEICAO', 'TP_ABRANGENCIA', 'SG_UE',
    'NM_UE', 'NR_ZONA', 'CD_CARGO', 'QT_APTOS_TOT', 'ST_VOTO_EM_TRANSITO',
    'HH_ULTIMA_TOTALIZACAO', 'DT_ULTIMA_TOTALIZACAO', 'QT_SECOES',
    'QT_SECOES_AGREGADAS', 'QT_SECOES_TOT', 'CD_MUNICIPIO', 'NM_MUNICIPIO',
    'QT_VOTOS_PENDENTES'
],
            axis=1,
            inplace=True)

# %%
df2018 = pd.read_csv('info_eleitores/detalhe_votacao_munzona_2018_BRASIL.csv',
                     encoding='ISO-8859-1',
                     sep=';')
df2018.drop([
    'DT_GERACAO', 'HH_GERACAO', 'CD_TIPO_ELEICAO', 'NM_TIPO_ELEICAO',
    'CD_ELEICAO', 'DS_ELEICAO', 'DT_ELEICAO', 'TP_ABRANGENCIA', 'SG_UE',
    'NM_UE', 'NR_ZONA', 'CD_CARGO', 'QT_APTOS_TOT', 'ST_VOTO_EM_TRANSITO',
    'HH_ULTIMA_TOTALIZACAO', 'DT_ULTIMA_TOTALIZACAO', 'QT_SECOES',
    'QT_SECOES_AGREGADAS', 'QT_SECOES_TOT', 'CD_MUNICIPIO', 'NM_MUNICIPIO',
    'QT_VOTOS_PENDENTES'
],
            axis=1,
            inplace=True)

# %%
df2020 = pd.read_csv('info_eleitores/detalhe_votacao_munzona_2020_BRASIL.csv',
                     encoding='ISO-8859-1',
                     sep=';')
df2020.drop([
    'DT_GERACAO', 'HH_GERACAO', 'CD_TIPO_ELEICAO', 'NM_TIPO_ELEICAO',
    'CD_ELEICAO', 'DS_ELEICAO', 'DT_ELEICAO', 'TP_ABRANGENCIA', 'SG_UE',
    'NM_UE', 'NR_ZONA', 'CD_CARGO', 'QT_APTOS_TOT', 'ST_VOTO_EM_TRANSITO',
    'HH_ULTIMA_TOTALIZACAO', 'DT_ULTIMA_TOTALIZACAO', 'QT_SECOES',
    'QT_SECOES_AGREGADAS', 'QT_SECOES_TOT', 'CD_MUNICIPIO', 'NM_MUNICIPIO',
    'QT_VOTOS_PENDENTES'
],
            axis=1,
            inplace=True)

# %% [markdown]
# # Tratamento inicial

# %%
df2014['QT_VOTOS_NULOS'] = df2014['QT_VOTOS_NULOS'] + df2014['QT_VOTOS_ANULADOS']
df2016['QT_VOTOS_NULOS'] = df2016['QT_VOTOS_NULOS'] + df2016['QT_VOTOS_ANULADOS']
df2018['QT_VOTOS_NULOS'] = df2018['QT_VOTOS_NULOS'] + df2018['QT_VOTOS_ANULADOS']
df2020['QT_VOTOS_NULOS'] = (df2020['QT_VOTOS_NULOS'] +
                            df2020['QT_VOTOS_ANULADOS'] +
                            df2020['QT_VOTOS_NULO_TECNICO'] +
                            df2020['QT_VOTOS_ANULADO_SUB_JUDICE'] +
                            df2020['QT_VOTOS_SEM_CAND_P_VOTAR'])
df2014.drop('QT_VOTOS_ANULADOS', axis=1, inplace=True)
df2016.drop('QT_VOTOS_ANULADOS', axis=1, inplace=True)
df2018.drop('QT_VOTOS_ANULADOS', axis=1, inplace=True)
df2020.drop(['QT_VOTOS_ANULADOS', 'QT_VOTOS_NULO_TECNICO',
             'QT_VOTOS_ANULADO_SUB_JUDICE', 'QT_VOTOS_SEM_CAND_P_VOTAR'],
           axis=1, inplace=True)

# %%
df = pd.concat([
    df1989, df1990, df1994, df1996, df1998, df2000, df2002, df2004, df2006,
    df2008, df2010, df2012, df2014, df2016, df2018, df2020
])
df = df.reset_index(drop=True)

# %%
df['DS_CARGO'] = df['DS_CARGO'].str.upper()
df['DS_CARGO'].unique()
# Out:
# array(['PRESIDENTE', 'GOVERNADOR', 'SENADOR', 'DEPUTADO FEDERAL',
#        'DEPUTADO ESTADUAL', 'DEPUTADO DISTRITAL', 'PREFEITO', 'VEREADOR',
#        nan,
#        'VOCÊ É A FAVOR | DA CRIAÇÃO DO MUNICÍPIO DE | EXTREMA DE RONDÔNIA?',
#        'VOCÊ É A FAVOR DA | ALTERAÇÃO DO NOME | DA CIDADE DE EMBU" | PARA "EMBU DAS ARTES"?"'],
#       dtype=object)

# %%
df['DS_CARGO'].replace(
    'VOCÊ É A FAVOR DA | ALTERAÇÃO DO NOME | DA CIDADE DE EMBU" | PARA "EMBU DAS ARTES"?"',
    np.nan,
    inplace=True)
df['DS_CARGO'].replace(
    'VOCÊ É A FAVOR | DA CRIAÇÃO DO MUNICÍPIO DE | EXTREMA DE RONDÔNIA?',
    np.nan,
    inplace=True)

# %%
df[df['ANO_ELEICAO'].isnull()]
# Out:
#         ANO_ELEICAO  NR_TURNO SG_UF DS_CARGO  QT_APTOS  QT_COMPARECIMENTO  \
# 17685           nan       nan   NaN      NaN       nan                nan
# 17686           nan       nan   NaN      NaN       nan                nan
# 17687           nan       nan   NaN      NaN       nan                nan
# 17688           nan       nan   NaN      NaN       nan                nan
# 17898           nan       nan   NaN      NaN       nan                nan
# 17899           nan       nan   NaN      NaN       nan                nan
# 17900           nan       nan   NaN      NaN       nan                nan
# 17901           nan       nan   NaN      NaN       nan                nan
# 208216          nan       nan   NaN      NaN       nan                nan
# 208217          nan       nan   NaN      NaN       nan                nan
# 208218          nan       nan   NaN      NaN       nan                nan
# 208219          nan       nan   NaN      NaN       nan                nan
#
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#         ANO_ELEICAO  NR_TURNO SG_UF    DS_CARGO   QT_APTOS  QT_COMPARECIMENTO  \
# 0           1989.00      1.00    AC  PRESIDENTE  182797.00          140309.00
# 1           1989.00      1.00    AL  PRESIDENTE 1210797.00          967803.00
# 2           1989.00      1.00    AM  PRESIDENTE  842083.00          626652.00
# 3           1989.00      1.00    AP  PRESIDENTE  118144.00           91937.00
# 4           1989.00      1.00    BA  PRESIDENTE 5893861.00         4711197.00
# ...             ...       ...   ...         ...        ...                ...
# 328106      2020.00      1.00    SP    PREFEITO    5850.00            4878.00
# 328107      2020.00      1.00    SP    PREFEITO   19726.00           14260.00
# 328108      2020.00      1.00    SP    PREFEITO   12808.00           10279.00
# 328109      2020.00      1.00    SP    PREFEITO    3510.00            3118.00
# 328110      2020.00      1.00    SP    PREFEITO    4665.00            3568.00
#
# ...

# %%
df['QT_BRANCOS_NULOS'] = df['QT_VOTOS_BRANCOS'] + df['QT_VOTOS_NULOS']
df.drop(['QT_VOTOS_BRANCOS', 'QT_VOTOS_NULOS'], axis=1, inplace=True)

# %% [markdown]
# # Group

# %%
df_grouped = df.groupby(['ANO_ELEICAO', 'NR_TURNO', 'SG_UF', 'DS_CARGO']).sum().reset_index()

# %% [markdown]
# ## Estados

# %%
df_grouped_last = df_grouped.groupby(['ANO_ELEICAO', 'SG_UF','NR_TURNO']
                                    ).last().reset_index().drop('DS_CARGO',
                                                                axis=1)
df_grouped_last.drop(['QT_VOTOS_NOMINAIS', 'QT_VOTOS_LEGENDA', 'QT_BRANCOS_NULOS'], axis=1, inplace=True)

# %%
df_estados_soma = df_grouped.groupby(['ANO_ELEICAO', 'SG_UF', 'NR_TURNO']).sum().reset_index()[[
    'ANO_ELEICAO', 'SG_UF', 'QT_VOTOS_NOMINAIS', 'QT_VOTOS_LEGENDA', 'QT_BRANCOS_NULOS'
]]

# %%
df_grouped_last.to_csv('exports/Info_eleitores_ano_estado_turno.csv', sep=';', decimal=',')
df_estados_soma.to_csv('exports/Info_eleitores_ano_estado_soma.csv', sep=';', decimal=',')

# %% [markdown]
# ## Estados - Cargos

# %%
df_grouped.to_csv('exports/Info_eleitores_cargos.csv', sep=';', decimal=',')
